# %% [markdown]
# # 📓 Day 3 — Big Data Engineering
# > **Date:** ___
# > **Theme:** File Operations + File Paths + Exception Handling

# %% [markdown]
# ## Videos
# - [X] #32 File Operation In Python (17min)
# - [X] #33 Working With File Paths (9min)
# - [ ] #34 Exception Handling In Python (25min)

# %% [markdown]
# ## 📘 Concepts to Know Before You Start
#
# ### File Operations
# - `open(file, mode)` — opens a file. Modes: `'r'` read, `'w'` write (overwrites), `'a'` append, `'rb'` read binary
# - Always use `with open(...) as f:` — it auto-closes the file even if an error happens
# - `f.read()` reads entire file, `f.readlines()` reads line by line into a list, `f.write()` writes string
#
# ### File Paths
# - `os.path.join('folder', 'file.txt')` → works on ALL operating systems (Windows uses `\`, Mac/Linux use `/`)
# - `pathlib.Path` is the modern way — `Path('folder') / 'file.txt'` does the same thing but cleaner
# - `Path.exists()`, `Path.stem` (filename without extension), `Path.parent` (parent folder), `Path.rglob('*.csv')` (find all csv files recursively)
#
# ### Exception Handling
# - `try` → code that might fail
# - `except SpecificError` → catches only that error (preferred over catching everything)
# - `else` → runs only if NO exception occurred
# - `finally` → ALWAYS runs, error or not (use for cleanup like closing files)
# - Always catch specific exceptions (`FileNotFoundError`, `ValueError`) not just `Exception` — otherwise you hide bugs
#
# ### Why this matters in Big Data
# In data pipelines, files are constantly being read, written, and moved. A pipeline that crashes without proper error handling can corrupt data or leave partial writes. Every real DE writes defensive file code.

# %% [markdown]
# ## Video Notes
# Write key concepts as you watch — use the guide above to check your understanding.

# %%
import os

for a,b,c in os.walk(os.getcwd()):
    print(a,b,c)
# Out:
# /kaggle/working [] ['__notebook__.ipynb']

# %%
# Video notes
# File modes —
# with open() —
# pathlib —
# try/except/finally —

# %% [markdown]
# ## Practice Questions (PQ)

# %% [markdown]
# ### PQ1
# What is the difference between open(file, 'r'), 'w', 'a', and 'rb'? When do you use each? Write one line of code showing each mode.

# %%
print('''r - will be used to read the file 
w - write the file it will override means delete the prev and add new data
a- it will append the data so it wont delete the prev data it will append on prev data 
rb- it is used on binary file it is used the read the binary file ''')

with open ("example.txt","w+") as f:
    f.write("hello world\n")

with open ("example.txt","r") as f:
   a = f.read()
print(a)

with open ("example.txt","a") as f:
   f.write("hello world part 2 \n")
    
with open ("example.txt","r") as f:
   b= f.read()
print(b)

with open ("example.txt","w") as f:
   f.write("this over ride and prev things got deleted")

with open ("example.txt","r") as f:
   c= f.read()
print(c)
# Out:
# r - will be used to read the file
# w - write the file it will override means delete the prev and add new data
# a- it will append the data so it wont delete the prev data it will append on prev data
# rb- it is used on binary file it is used the read the binary file
# hello world
#
# hello world
# hello world part 2
#
# this over ride and prev things got deleted

# %% [markdown]
# ### PQ2
# What does `with open(...) as f` do? Why is it better than manually calling f.close()? Show what happens if you DON'T use with and an error occurs mid-read.

# %%
print('''with open(...) as f it is used to go to that file and perform any actions on it 
f.close i am guessing it is used to go out of file i have to read more about this 
no knowledfge u can provide more insights on this 
''')
# Out:
# with open(...) as f it is used to go to that file and perform any actions on it
# f.close i am guessing it is used to go out of file i have to read more about this
# no knowledfge u can provide more insights on this

# %% [markdown]
# ### PQ3
# Using pathlib, write code that: (a) creates a Path object for 'data/sales.csv', (b) prints the filename without extension, (c) prints the parent directory name.

# %%
print(''' i havent used more path lib but it is modern way of using os that i know i will answer these using os and try to give using pathlib ''')
import os
print(os.path.join("data","sales.csv"))

import pathlib

from pathlib import Path

a=Path("data_2")/"sales_2.csv"

print(a)

Path("My_Folder").mkdir
z=Path.cwd
print(z)
# Out:
#  i havent used more path lib but it is modern way of using os that i know i will answer these using os and try to give using pathlib
# data/sales.csv
# data_2/sales_2.csv
# <bound method Path.cwd of <class 'pathlib.Path'>>

# %% [markdown]
# ### PQ4
# Write a try/except/else/finally skeleton. In each block write a comment explaining exactly when that block runs.

# %%
# PQ4

# %% [markdown]
# ### PQ5
# What is wrong with this code? Fix it and explain why:
# ```python
# try:
#     result = 10 / 0
# except Exception:
#     print('something went wrong')
# ```

# %%
# PQ5 — fix the code and explain

# %% [markdown]
# ## Homework (HW)
# > Complete by 5 PM next day (office hours)

# %% [markdown]
# ### HW1
# Create a file called 'sample.txt' with 5 lines of text (use Python to write it). Then read it back and print each line with its line number. Use `with open()` for both operations.

# %%
with open("sample.txt",'w') as f:
    f.write(" this is line 1\n this is line 2\n this is line 3\n this is line 4\n this is line 5\n")
with open("sample.txt",'r') as f: 
    
    count =1
    for i in f:
        print(count,i)
        count+=1
# Out:
# 1  this is line 1
#
# 2  this is line 2
#
# 3  this is line 3
#
# 4  this is line 4
#
# 5  this is line 5

# %% [markdown]
# ### HW2
# Write a function `safe_read(filepath)` that: (a) tries to open and read the file, (b) catches FileNotFoundError with a clear message 'File not found: {filepath}', (c) catches PermissionError with a different message 'No permission to read: {filepath}', (d) always prints 'Read attempt complete' at the end. Test it with a real file and a fake path.

# %%
## pending

# %% [markdown]
# ### HW3
# You skipped collections yesterday — do it now! Use Counter to count word frequency in: 'the cat sat on the mat the cat'. Then use defaultdict(list) to group these words by their first letter: ['apple', 'ant', 'banana', 'cherry', 'cat', 'avocado']. Print both results clearly.

# %%
# HW3
from collections import Counter, defaultdict

# %% [markdown]
# ### HW4
# Using pathlib only (no os.path): (a) create a Path for any folder on your system, (b) check if it exists, (c) list all .ipynb files in it, (d) for each file print just the filename without extension. If folder doesn't exist, catch the error gracefully.

# %%
# HW4

# %% [markdown]
# ### HW5 — 🔀 Mixed (filter + files + exceptions)
# This connects Day 2 and Day 3. Write a function `read_errors_only(filepath)` that: reads a text file line by line, uses filter() to keep only lines containing 'ERROR', prints the count of error lines found, handles FileNotFoundError if the file doesn't exist.
#
# Create a fake log file first with some ERROR and INFO lines, then test your function on it.

# %%
# HW5

# %% [markdown]
# ## SQL
# > Topic: GROUP BY, HAVING, Aggregate Functions
#
# ### 📘 Quick concept reminder:
# - `GROUP BY` groups rows with the same value together
# - Aggregate functions work on groups: `COUNT()`, `SUM()`, `AVG()`, `MAX()`, `MIN()`
# - `WHERE` filters BEFORE grouping (filters individual rows)
# - `HAVING` filters AFTER grouping (filters groups)
# - Rule: if you use an aggregate in your condition, use HAVING not WHERE

# %% [markdown]
# ### SQL1
# Table: orders(order_id, customer_id, amount, city)
# Write a query to find cities where the TOTAL order amount exceeds 10000. Show city name and total amount, ordered by total amount DESC.

# %%
sql1 = """
select city,sum(amount) as total_amount
from orders
group by city
having sum(amount)>10000
"""
print(sql1)
# Out:
# select city,sum(amount) as total_amount
# from orders
# group by city
# having sum(amount)>10000

# %% [markdown]
# ### SQL2
# Table: employees(id, name, department, salary)
# Find the average salary per department, but only show departments where the average salary is above 50000. Also show how many employees are in each of those departments.

# %%
sql2 = """
select department, avg(salary) as avg_salary,count(id) as no_of_people
from employees
group by department 
having avg(salary)>50000
"""
print(sql2)
# Out:
# select department, avg(salary) as avg_salary,count(id) as no_of_people
# from employees
# group by department
# having avg(salary)>50000

# %% [markdown]
# ## Notes
# Write anything you want to remember from today — especially the difference between WHERE and HAVING, that trips everyone up.

# %%
# Notes

# Time spent: 0 mins  <-- update this!
time_spent = 90
print(f'Time spent: {time_spent} mins')
# Out:
# Time spent: 90 mins
