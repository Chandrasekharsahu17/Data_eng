# %% [markdown]
# ## Pandas -- Data Frame and series

# %%
pip install pandas

# %%
import pandas as pd

# %%
## series - 1 dimesnion tabular data

## create a series from a list

data=[1,2,3,4,5]
series=pd.Series(data)
series
print(type(series))

# %%
## create a series from a dict
a={"a":12,"b":13,"c":15}
series_dict=pd.Series(a)
series_dict

# %%
data=[1,2,3,4,5]
index= ["a","b","c","d","e"]

s=pd.Series(data,index=index)

# %%
# Data Frame - multiple rows and column

# create a DF from of a dict of list

data={
    "name":["Chandra","john","jack"],
    "age": [12,17,20],
    "city":["bng",'texas',"delhi"]
}
df=pd.DataFrame(data)
df

# %%
## create df from list of dict

data={
    {"name":["Chandra","john","jack"]},
    "age": [12,17,20],
    "city":["bng",'texas',"delhi"]
}

# %%
df=pd.read_csv('/kaggle/input/datasets/chandrasekharsahu17/data-csv/data.csv')

# %%
df.head()

# %%
## Row Index

df.loc[0]

# %%
# column index 

df.iloc[0]

# %%
df.loc[0][0]

# %%
## accessing specified element

df["Region"].unique()

# %%
df.at[2,'Sales']

# %%
df.iat[2,2]

# %%
# Data Manipuklation in DF

df['Salary']=400

# %%
df.head()

# %%
df.drop('Salary',axis=1,inplace=True)

# %%
df.head()

# %%
df['Sales']=df["Sales"]+50

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_57/964094849.py in <cell line: 0>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.drop(3,inplace=True)

# %%
df.describe()

# %%
df.head(5)
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
df.tail(5)
# Out:
#           Date Category  Value   Product  Sales Region
# 45  2023-02-15        B   99.0  Product2  599.0   West
# 46  2023-02-16        B    6.0  Product1  938.0  South
# 47  2023-02-17        B   69.0  Product3  143.0   West
# 48  2023-02-18        C   65.0  Product3  182.0  North
# 49  2023-02-19        C   11.0  Product3  708.0  North

# %%
df.dtypes
# Out:
# Date         object
# Category     object
# Value       float64
# Product      object
# Sales       float64
# Region       object
# dtype: object

# %%
## handelling missuing values

df.isnull().sum()
# Out:
# Date            0
# Category        0
# Value           3
# Product         0
# Sales           4
# Region          0
# fill_salesNa    0
# dtype: int64

# %%
df_filled=df.fillna(0)

# %%
df["fill_salesNa"]=df['Sales'].fillna(df['Sales'].mean())

# %%
df.head(5)
# Out:
#          Date Category  Value   Product  Sales Region  fill_salesNa
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0

# %%
## Renaming column
## rename should be done in key value pair 

df=df.rename(columns={"Date":"Sale Date"})

df.head()
# Out:
#     Sale Date Category  Value   Product  Sales Region  fill_salesNa
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0
